# %%
import pandas as pd 
import matplotlib.pyplot as plt
import numpy as np

# %%
dd = pd.read_csv('scp.dat', delimiter=' ', names=["SN","z","sigma z","m X peak","sigma X peak","A X","K BX","m B peak","m B eff","sigma m B eff","NOTES"])
dx = dd.to_numpy()

# %%
dx
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_7552/2823488498.py in <module>
# ----> 1 dx
#
# NameError: name 'dx' is not defined

# %%
dd.plot(kind = 'scatter', x = 'z', y = 'm B eff')
dd.plot(kind = "scatter", x="z",y="sigma X peak")
# Out:
# <AxesSubplot: xlabel='z', ylabel='sigma X peak'>
